# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
# map tophat / WGS, use pcawg
wgs_pcawg = pd.read_csv("WGS_PCAWG.96.csv")
tophat_star = pd.read_csv("tophat_star_fpkm_uq.v2_aliquot_gl.tsv", sep="\t")
pcawg_specimen_histology = pd.read_excel("pcawg_specimen_histology_August2016_v9.xlsx")

# %%
wgs_pcawg.head()
# Out:
#   Mutation type Trinucleotide  Biliary-AdenoCA::SP117655  \
# 0           C>A           ACA                        269
# 1           C>A           ACC                        148
# 2           C>A           ACG                         25
# 3           C>A           ACT                        154
# 4           C>A           CCA                        215
#
#    Biliary-AdenoCA::SP117556  Biliary-AdenoCA::SP117627  \
# 0                        114                        105
# 1                         56                         71
# 2                         13                         13
# 3                         70                         73
# 4                         63                         71
#
#    Biliary-AdenoCA::SP117775  Biliary-AdenoCA::SP117332  \
# 0                        217                         52
# 1                        123                         36
# 2                         29                          8
# ...

# %%
tophat_star.head()
# Out:
#               feature  00055bad-54b7-4898-a9ae-3dd8036e62d3  \
# 0  ENSG00000000003.10                             65.515874
# 1   ENSG00000000005.5                              0.046881
# 2   ENSG00000000419.8                             63.315522
# 3   ENSG00000000457.9                              2.222857
# 4  ENSG00000000460.12                              2.565836
#
#    0031d433-d703-4b2c-9fdf-2920008eb457  0046fef7-052b-4d4e-b264-b3bf2e2699b1  \
# 0                             93.507754                             15.155525
# 1                              0.655002                              0.000000
# 2                             23.608843                             42.136192
# 3                              1.933762                              2.318698
# 4                              1.861716                              2.870440
#
#    008292c8-81f5-4930-b179-a198686fc79b  00b6a02c-1b13-4b9a-b63f-400230f83973  \
# ...

# %%
pcawg_specimen_histology.head()
# Out:
#   # icgc_specimen_id project_code submitted_specimen_id submitted_sample_id  \
# 0             SP2143      BRCA-UK  CGP_specimen_1142534             PD3851a
# 1             SP2144      BRCA-UK  CGP_specimen_1096043             PD3890a
# 2             SP2145      BRCA-UK  CGP_specimen_1142475             PD3904a
# 3             SP2146      BRCA-UK  CGP_specimen_1142532             PD3905a
# 4             SP2147      BRCA-UK  CGP_specimen_1195364             PD3945a
#
#   tcga_specimen_uuid icgc_sample_id tcga_sample_uuid  \
# 0                NaN         SA6125              NaN
# 1                NaN         SA6128              NaN
# 2                NaN         SA6131              NaN
# 3                NaN         SA6134              NaN
# 4                NaN         SA6137              NaN
#
#               donor_unique_id icgc_donor_id submitted_donor_id  ...  \
# 0  BRCA-UK::CGP_donor_1114930        DO1000  CGP_donor_1114930  ...
# ...

# %%
features = tophat_star['feature'][:500]
tophat = []

for feature in tqdm(features):
    vals = tophat_star[tophat_star['feature'] == feature]
    uuids = vals.columns.tolist()[1:]
    for uuid in uuids:
        row = {"feature": feature, "uuid": uuid, "value": vals[uuid].values[0]}
        tophat.append(row)

tophat_df = pd.DataFrame(tophat)
tophat_df.head()
# Out:
# 100%|████████████████████████████████████████████████████| 500/500 [00:12<00:00, 38.56it/s]
#               feature                                  uuid      value
# 0  ENSG00000000003.10  00055bad-54b7-4898-a9ae-3dd8036e62d3  65.515874
# 1  ENSG00000000003.10  0031d433-d703-4b2c-9fdf-2920008eb457  93.507754
# 2  ENSG00000000003.10  0046fef7-052b-4d4e-b264-b3bf2e2699b1  15.155525
# 3  ENSG00000000003.10  008292c8-81f5-4930-b179-a198686fc79b   9.751670
# 4  ENSG00000000003.10  00b6a02c-1b13-4b9a-b63f-400230f83973   0.005517

# %%
tophat_df.columns = ["UserId", "ItemId", "Rating"]
tophat_df.head()
# Out:
#                UserId                                ItemId     Rating
# 0  ENSG00000000003.10  00055bad-54b7-4898-a9ae-3dd8036e62d3  65.515874
# 1  ENSG00000000003.10  0031d433-d703-4b2c-9fdf-2920008eb457  93.507754
# 2  ENSG00000000003.10  0046fef7-052b-4d4e-b264-b3bf2e2699b1  15.155525
# 3  ENSG00000000003.10  008292c8-81f5-4930-b179-a198686fc79b   9.751670
# 4  ENSG00000000003.10  00b6a02c-1b13-4b9a-b63f-400230f83973   0.005517

# %%
# TODO - get sideinfo matrices

# %% [markdown]
# ## Fit Model

# %%
from cmfrec import CMF

# Without sideinfo

model_no_sideinfo = CMF(method = "als", k = 40, lambda_ = 1e+1)
model_no_sideinfo.fit(tophat_df)
# Out:
# Starting ALS optimization routine
#
# Updating B ...
# /Users/eesha/miniconda3/envs/pyenv/lib/python3.9/site-packages/cmfrec/__init__.py:132: UserWarning: Attempting to use more than 1 thread, but package was built without multi-threading support - see the project's GitHub page for more information.
#   warnings.warn(msg_omp)
#  done
# Updating A ... done
# 	Completed ALS iteration  1
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  2
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  3
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  4
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  5
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  6
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  7
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  8
#
# Updating B ... done
# Updating A ... done
# 	Completed ALS iteration  9
#
# ...

# %%
from cmfrec import ContentBased
# with side info

model_with_sideinfo = ContentBased(k=40, maxiter=0, user_bias=False, item_bias=False)

# Fit actual side info

# model_content_based.fit(X=ratings.loc[ratings.ItemId.isin(item_sideinfo_pca.ItemId)],
#                         U=user_side_info,
#                         I=item_sideinfo_pca.loc[item_sideinfo_pca.ItemId.isin(ratings.ItemId)])
